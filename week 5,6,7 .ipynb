# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
np.random.seed(42)
x = np.linspace(0, 10, 50)
y = np.sin(x) + np.random.normal(0, 0.2, 50)

# %%
# Line plot (Matplotlib)
plt.figure(figsize=(10, 4))
plt.plot(x, y, label='Line Plot', color='blue')
plt.title("Basic Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Scatter plot (Matplotlib)
plt.figure(figsize=(10, 4))
plt.scatter(x, y, label='Scatter Plot', color='red')
plt.title("Basic Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a DataFrame for Seaborn plots
df = pd.DataFrame({
    "values": np.random.normal(loc=50, scale=10, size=100),
    "category": np.random.choice(["A", "B"], size=100)
})
df.head()
# Out:
#       values category
# 0  53.240840        B
# 1  46.149177        B
# 2  43.230780        B
# 3  56.116763        A
# 4  60.309995        B

# %%
# Histogram (Seaborn)
plt.figure(figsize=(10, 4))
sns.histplot(df["values"], bins=20, kde=True, color="skyblue")
plt.title("Histogram with KDE (Seaborn)")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
# Box plot (Seaborn)
plt.figure(figsize=(10, 4))
sns.boxplot(x="category", y="values", data=df)
plt.title("Box Plot by Category (Seaborn)")
plt.xlabel("Category")
plt.ylabel("Values")
plt.show()
